# %%
import requests

# %%
# Go to poe ninja and pull divination card prices for the current league

# %%
poe_ninja_divination_data = requests.get('https://poe.ninja/api/data/itemoverview?league=Sanctum&type=DivinationCard&language=en')
print(poe_ninja_divination_data.json())
# Out:
# {'lines': [{'id': 95761, 'name': 'The Apothecary', 'icon': 'https://web.poecdn.com/gen/image/WzI1LDE0LHsiZiI6IjJESXRlbXMvRGl2aW5hdGlvbi9JbnZlbnRvcnlJY29uIiwidyI6MSwiaCI6MSwic2NhbGUiOjF9XQ/f34bf8cbb5/InventoryIcon.png', 'stackSize': 5, 'artFilename': 'TheApothecary', 'itemClass': 6, 'sparkline': {'data': [0, 3.37, 4.64, 5.11, 3.73, 3.14, 5.18], 'totalChange': 5.18}, 'lowConfidenceSparkline': {'data': [0, 3.37, 4.64, 5.11, 3.73, 3.14, 5.18], 'totalChange': 5.18}, 'implicitModifiers': [], 'explicitModifiers': [{'text': '<uniqueitem>{Mageblood}', 'optional': False}], 'flavourText': '"You seek the power of my strongest potions, but the price will be far higher than you can imagine."', 'chaosValue': 15724.4, 'exaltedValue': 779.59, 'divineValue': 62.14, 'count': 99, 'detailsId': 'the-apothecary', 'listingCount': 283}, {'id': 636, 'name': 'House of Mirrors', 'icon': 'https://web.poecdn.com/gen/image/WzI1LDE0LHsiZiI6IjJESXRlbXMvRGl2aW5hdGlvbi9JbnZlbnRvcnlJY29uIiwidyI6MSwiaCI6MSwic2NhbGUiOjF9XQ/f34bf8cbb5/InventoryIcon.png', 'stackSize': 9, 'artFilename': 'HouseOfMirrors', 'itemClass': 6, 'sparkline': {'data': [0, -0.1, -2.33, -1.18, 3.62, 3.94, 6.65], 'totalChange': 6.65}, 'lowConfidenceSparkline': {'data': [0, -0.1, -2.33, -1.18, 3.62, 3.94, 6.65], 'totalChange': 6.65}, 'implicitModifiers': [], 'explicitModifiers': [{'text': '<currencyitem>{Mirror of Kalandra}', 'optional': False}], 'flavourText': 'What do you see in the mirror?', 'chaosValue': 10122.0, 'exaltedValue': 501.83, 'divineValue': 40.0, 'count': 99, 'detailsId': 'house-of-mirrors', 'listingCount': 153}, {'id': 98384, 'name': 'The Price of Devotion', 'icon': 'https://web.poecdn.com/gen/image/WzI1LDE0LHsiZiI6IjJESXRlbXMvRGl2aW5hdGlvbi9JbnZlbnRvcnlJY29uIiwidyI6MSwiaCI6MSwic2NhbGUiOjF9XQ/f34bf8cbb5/InventoryIcon.png', 'stackSize': 7, 'artFilename': 'ThePriceOfDevotion', 'itemClass': 6, 'sparkline': {'data': [0, 6.21, 2.74, 1.23, 4.13, 9.23, 15.72], 'totalChange': 15.72}, 'lowConfidenceSparkline': {'data': [0, 6.21, 2.74, 1.23, 4.13, 9.23, 15.72], 'totalChange': 15.72}, 'implicitModifiers': [], 'explicitModifiers': [{'text': '<uniqueitem>{Mageblood}\n<default>{Quality:} <augmented>{+20%}\n<corrupted>{Two-Implicit}\n<corrupted>{Corrupted}', 'optional': False}], 'flavourText': "<size:30>{Unbeknown to Atziri's finest thaumaturgists, their loyalty would require far greater devotion than mere research.}", 'chaosValue': 9868.95, 'exaltedValue': 489.29, 'divineValue': 39.0, 'count': 24, 'detailsId': 'the-price-of-devotion', 'listingCount': 30}, {'id': 100726, 'name': 'The Insane Cat', 'icon': 'https://web.poecdn.com/gen/image/WzI1LDE0LHsiZiI6IjJESXRlbXMvRGl2aW5hdGlvbi9JbnZlbnRvcnlJY29uIiwidyI6MSwiaCI6MSwic2NhbGUiOjF9XQ/f34bf8cbb5/InventoryIcon.png', 'stackSize': 9, 'artFilename': 'TheInsaneCat', 'itemClass': 6, 'sparkline': {'data': [0, 3.67, 1.63, 5.01, 7.19, 14.32, 8.12], 'totalChange': 8.12}, 'lowConfidenceSparkline': {'data': [0, 3.67, 1.63, 5.01, 7.19, 14.32, 8.12], 'totalChange': 8.12}, 'implicitModifiers': [], 'explicitModifiers': [{'text': '<uniqueitem>{Mageblood}\n<default>{Item Level:} <normal>{84}\n<corrupted>{Corrupted}', 'optional': False}], 'flavourText': "One person's madness is another person's reality.", 'chaosValue': 6073.2, 'exaltedValue': 301.1, 'divineValue': 24.0, 'count': 95, 'detailsId': 'the-insane-cat', 'listingCount': 101}, {'id': 44612, 'name': 'Unrequited Love', 'icon': 'https://web.poecdn.com/gen/image/WzI1LDE0LHsiZiI6IjJESXRlbXMvRGl2aW5hdGlvbi9JbnZlbnRvcnlJY29uIiwidyI6MSwiaCI6MSwic2NhbGUiOjF9XQ/f34bf8cbb5/InventoryIcon.png', 'stackSize': 16, 'artFilename': 'UnrequitedLove', 'itemClass': 6, 'sparkline': {'data': [0, 3.81, 5.56, 8.95, 9.84, 12.61, 17.15], 'totalChange': 17.15}, 'lowConfidenceSparkline': {'data': [0, 3.81, 5.56, 8.95, 9.84, 12.61, 17.15], 'totalChange': 17.15}, 'implicitModifiers': [], 'explicitModifiers': [{'text': '<currencyitem>{19x Mirror Shard}', 'optional': False}], 'flavourText': '<size:26>{The pale flame of his heart disappeared in  ...
